# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from gtts import gTTS
from io import BytesIO
from pydub import AudioSegment
from pathlib import Path
from audio_tools.process import process_pod, process_podcast_folder, split_podcast, full_process_podcast_episode

# %%
podcast_path = Path('../data/Dwarkesh Karpathy Interview.mp3')
output_folder_path = Path('../data/processed_podcasts/')

split_podcast([podcast_path], output_folder_path=output_folder_path, split_length=15)


output_folder_path2 = Path('../data/karpathy2')
process_podcast_folder(output_folder_path, output_folder_path=output_folder_path2, db_change = 5)

# %%
podcast_path = Path('../data/80000 Hours Holden Karnofsky.mp3')
full_process_podcast_episode(podcast_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 podcast_path = Path('../data/80000 Hours Holden Karnofsky.mp3')
# ----> 2 full_process_podcast_episode(podcast_path)
#
# File ~/Documents/github/audio_tools/audio_tools/process.py:162, in full_process_podcast_episode(filepath, db_change)
#     159 if not output_folder.exists():
#     160     output_folder.mkdir(parents=True, exist_ok=True)
# --> 162 split_podcast(
#     163     filepaths=[filepath],
#     164     output_folder_path=output_folder,
#     165     split_length=15,
#     166 )
#     168 process_podcast_folder(
#     169     folder_path=output_folder,
#     170     output_folder_path=output_folder,
#     171     db_change=db_change,
#     172 )
#     174 return output_folder
#
# ...
